# %% [markdown]
# #### The outcome of the following code gives rise to the SQL code that allows to insert all data in the correct tables in the SQL database

# %%
import pandas as pd

#region currencies

df_currencies = pd.read_csv("demo_raw_data_currencies.csv", delimiter=";")

df_currencies.columns

string_header = ""
for i in df_currencies.columns:
    string_header += i + ","
#print (string_header)

string_code_base = "INSERT INTO investments.currencies (" + string_header[:len(string_header)-1] + ") VALUES "
#print (string_code_base)
for i in df_currencies.values:
    temp_tuple = tuple (i)
#    print (temp_tuple)
    string_cod = string_code_base + str(temp_tuple) + ";"
    string_cod = string_cod.replace(", nan", ", NULL")

    print (string_cod)

#endregion

#region alocations

df_alocations = pd.read_csv("demo_raw_data_alocations.csv", delimiter=";")

df_alocations.columns

string_header = ""
for i in df_alocations.columns:
    string_header += i + ","
#print (string_header)

string_code_base = "INSERT INTO investments.alocations (" + string_header[:len(string_header)-1] + ") VALUES "
#print (string_code_base)
for i in df_alocations.values:
    temp_tuple = tuple (i)
#    print (temp_tuple)
    string_cod = string_code_base + str(temp_tuple) + ";"
    string_cod = string_cod.replace(", nan", ", NULL")

    print (string_cod)

#endregion

#region geographies

df_geographies = pd.read_csv("demo_raw_data_geographies.csv", delimiter=";")

df_geographies.columns

string_header = ""
for i in df_geographies.columns:
    string_header += i + ","
#print (string_header)

string_code_base = "INSERT INTO investments.geographies (" + string_header[:len(string_header)-1] + ") VALUES "
#print (string_code_base)
for i in df_geographies.values:
    temp_tuple = tuple (i)
#    print (temp_tuple)
    string_cod = string_code_base + str(temp_tuple) + ";"
    string_cod = string_cod.replace(", nan", ", NULL")

    print (string_cod)

#endregion

#region stock exchanges

df_ses = pd.read_csv("demo_raw_data_stockexcs.csv", delimiter=";")

df_ses.columns

string_header = ""
for i in df_ses.columns:
    string_header += i + ","
#print (string_header)

string_code_base = "INSERT INTO investments.stockexcs (" + string_header[:len(string_header)-1] + ") VALUES "
#print (string_code_base)
for i in df_ses.values:
    temp_tuple = tuple (i)
#    print (temp_tuple)
    string_cod = string_code_base + str(temp_tuple) + ";"
    string_cod = string_cod.replace(", nan", ", NULL")

    print (string_cod)

#endregion

#region tipologies

df_tipologies = pd.read_csv("demo_raw_data_tipologies.csv", delimiter=";")

df_tipologies.columns

string_header = ""
for i in df_tipologies.columns:
    string_header += i + ","
#print (string_header)

string_code_base = "INSERT INTO investments.tipologies (" + string_header[:len(string_header)-1] + ") VALUES "
#print (string_code_base)
for i in df_tipologies.values:
    temp_tuple = tuple (i)
#    print (temp_tuple)
    string_cod = string_code_base + str(temp_tuple) + ";"
    string_cod = string_cod.replace(", nan", ", NULL")

    print (string_cod)

#endregion

#region products

df_products = pd.read_csv("demo_raw_data_products.csv", delimiter=";")

df_products.columns

string_header = ""
for i in df_products.columns:
    string_header += i + ","
#print (string_header)

string_code_base = "INSERT INTO investments.products (" + string_header[:len(string_header)-1] + ") VALUES "
#print (string_code_base)
for i in df_products.values:
    temp_tuple = tuple (i)
#    print (temp_tuple)
    string_cod = string_code_base + str(temp_tuple) + ";"
    string_cod = string_cod.replace(", nan", ", NULL")

    print (string_cod)

#endregion

#region orders

df_orders = pd.read_csv("demo_raw_data_orders.csv", delimiter=";", parse_dates=True)

df_orders['date'] = pd.to_datetime(df_orders['date'], dayfirst=True)
df_orders ["date"] = df_orders['date'].dt.strftime('%Y%m%d')

df_orders.columns

string_header = ""
for i in df_orders.columns:
    string_header += i + ","
#print (string_header)

string_code_base = "INSERT INTO investments.orders (" + string_header[:len(string_header)-1] + ") VALUES "
#print (string_code_base)
for i in df_orders.values:
    temp_tuple = tuple (i)
#    print (temp_tuple)
    string_cod = string_code_base + str(temp_tuple) + ";"
    string_cod = string_cod.replace(", nan", ", NULL")

    print (string_cod)

#endregion
# Out:
# INSERT INTO investments.currencies (currency_id,currency) VALUES (1, 'DKK');
# INSERT INTO investments.currencies (currency_id,currency) VALUES (2, 'EUR');
# INSERT INTO investments.currencies (currency_id,currency) VALUES (3, 'USD');
# INSERT INTO investments.alocations (alocation_id,alocation_description,perc_stocks,perc_bonds,perc_gold,perc_crypto,perc_other_fin_instruments) VALUES (1, '100% Stocks', 100.0, 0.0, 0, 0, 0.0);
# INSERT INTO investments.alocations (alocation_id,alocation_description,perc_stocks,perc_bonds,perc_gold,perc_crypto,perc_other_fin_instruments) VALUES (2, '100% Bonds', 0.0, 100.0, 0, 0, 0.0);
# INSERT INTO investments.alocations (alocation_id,alocation_description,perc_stocks,perc_bonds,perc_gold,perc_crypto,perc_other_fin_instruments) VALUES (3, '100% Gold', 0.0, 0.0, 100, 0, 0.0);
# ...
